# %% [markdown]
# <a href="https://colab.research.google.com/github/Manohar-123272/Deepfake/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
!7z x /content/drive/MyDrive/DEEPFAKE.7z -o/content/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1183385632 bytes (1129 MiB)
#
# Extracting archive: /content/drive/MyDrive/DEEPFAKE.7z
# --
# Path = /content/drive/MyDrive/DEEPFAKE.7z
# Type = 7z
# Physical Size = 1183385632
# Headers Size = 151745
# Method = LZMA:23
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 4
# Files: 13005
# Size:       1197902839
# Compressed: 1183385632

# %%
# !pip install -r /content/DEEPFAKE/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44284 sha256=5a8431ac0d9079463f84d00059f8350034e81cfe65ff28417cf2e84626e0b698
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# Successfully built grad-cam
# ...

# %%
# %cd /content/DEEPFAKE
# Out:
# /content/DEEPFAKE

# %%
# !python main.py
# Out:
# Loaded 13000 images: 8000 real, 5000 fake
# Loaded 13000 images: 8000 real, 5000 fake
# Loaded 13000 images: 8000 real, 5000 fake
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Dataset splits: Train=9100, Val=1950, Test=1950
#
# ...
# Training Swin Transformer Model
# ...
# Using device: cuda
# Epoch 1/20 [Train]: 100% 285/285 [02:04<00:00,  2.29it/s, Loss=0.5821, Acc=67.67%]
# Epoch 1/20:
# Train Loss: 0.6486, Train Acc: 67.67%
# Val Loss: 0.4639, Val Acc: 80.62%
# --------------------------------------------------
# ...
